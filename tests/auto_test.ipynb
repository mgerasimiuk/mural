# %%
import sys
sys.path.insert(1, "../mural")

# %%
from base import *
from test import *

# %%
SR, labels = make_embedded_swiss_roll(5)

# %%
SR_missing, SR_imputed = make_missing_middle(SR, [300, 300,], [0, 1,])

# %%
make_embeddings(SR_imputed, labels)
# Out:
# Calculating PHATE...
#   Running PHATE on 3000 observations and 5 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.11 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.04 seconds.
#   Calculated graph and diffusion operator in 0.17 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 0.40 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 19.53 seconds.
#   Calculated landmark operator in 21.47 seconds.
#   Calculating optimal t...
#     Automatically selected t = 48
#   Calculated optimal t in 4.49 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 1.77 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 13.77 seconds.
# Calculated PHATE in 41.68 seconds.

# %%
demap_reference(SR_imputed)

# %%
os.getcwd()
